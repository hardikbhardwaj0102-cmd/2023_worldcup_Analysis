# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # BATTING ANALYSIS

# %%
df1=pd.read_csv(r"C:\@Hardik\Data Science\Project_2023_ODI_WC\archive (1)\ICC MENS ODI WORLD CUP 2023\Batting records\most_runs.csv")

# %%
df1
# Out:
#                      Player       Span  Mat  Inns  NO Runs    HS    Ave   BF  \
# 0             V Kohli (IND)  2023-2023   11    11   3  765   117  95.62  847
# 1           RG Sharma (IND)  2023-2023   11    11   0  597   131  54.27  474
# 2            Q de Kock (SA)  2023-2023   10    10   0  594   174  59.40  555
# 3           R Ravindra (NZ)  2023-2023   10    10   1  578  123*  64.22  543
# 4          DJ Mitchell (NZ)  2023-2023   10     9   1  552   134  69.00  497
# ..                      ...        ...  ...   ...  ..  ...   ...    ...  ...
# 141      MADI Hemantha (SL)  2023-2023    2     2   1    4    4*   4.00    4
# 142      JR Hazlewood (AUS)  2023-2023   11     5   3    4     2   2.00    5
# 143  Fazalhaq Farooqi (AFG)  2023-2023    6     3   2    2    2*   2.00    9
# 144          AT Carey (AUS)  2023-2023    1     1   0    -     0   0.00    2
# 145         Usama Mir (PAK)  2023-2023    4     1   0    -     0   0.00    3
#
#          SR 100 50  0  4s  6s
# ...

# %%
df1.head()
# Out:
#              Player       Span  Mat  Inns  NO Runs    HS    Ave   BF      SR  \
# 0     V Kohli (IND)  2023-2023   11    11   3  765   117  95.62  847   90.31
# 1   RG Sharma (IND)  2023-2023   11    11   0  597   131  54.27  474  125.94
# 2    Q de Kock (SA)  2023-2023   10    10   0  594   174  59.40  555  107.02
# 3   R Ravindra (NZ)  2023-2023   10    10   1  578  123*  64.22  543  106.44
# 4  DJ Mitchell (NZ)  2023-2023   10     9   1  552   134  69.00  497  111.06
#
#   100 50  0  4s  6s
# 0   3  6  1  68   9
# 1   1  3  1  66  31
# 2   4  -  -  57  21
# 3   3  2  -  55  17
# 4   2  2  -  48  22

# %%
df1.isnull()
# Out:
#      Player   Span    Mat   Inns     NO   Runs     HS    Ave     BF     SR  \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ..      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 141   False  False  False  False  False  False  False  False  False  False
# 142   False  False  False  False  False  False  False  False  False  False
# 143   False  False  False  False  False  False  False  False  False  False
# 144   False  False  False  False  False  False  False  False  False  False
# 145   False  False  False  False  False  False  False  False  False  False
#
#        100     50      0     4s     6s
# ...

# %%
df1.isnull().sum()
# Out:
# Player    0
# Span      0
# Mat       0
# Inns      0
# NO        0
# Runs      0
# HS        0
# Ave       0
# BF        0
# SR        0
# 100       0
# 50        0
# 0         0
# 4s        0
# 6s        0
# dtype: int64

# %% [markdown]
# ## REPLACING "-" WITH 0 IN DATAFRAME

# %%
df1=df1.replace("-",value="0")

# %% [markdown]
# ## REMOVING *(NOT OUT) FROM HIGH SCORE(HS)

# %%
df1['HS'] = df1['HS'].astype(str).str.replace('*','', regex=False)

# %% [markdown]
# ## CONVERING ALL COLUMNS FROM STRING TO NUMERIC

# %%
cols = ['Mat','Inns','NO','Runs','HS','Ave','BF','SR','100','50','0','4s','6s']

df1[cols] = df1[cols].apply(pd.to_numeric)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  146 non-null    object
#  1   Span    146 non-null    object
#  2   Mat     146 non-null    int64
#  3   Inns    146 non-null    int64
#  4   NO      146 non-null    int64
#  5   Runs    146 non-null    int64
#  6   HS      146 non-null    int64
#  7   Ave     146 non-null    float64
#  8   BF      146 non-null    int64
#  9   SR      146 non-null    float64
#  10  100     146 non-null    int64
#  11  50      146 non-null    int64
#  12  0       146 non-null    int64
#  13  4s      146 non-null    int64
#  14  6s      146 non-null    int64
# dtypes: float64(2), int64(11), object(2)
# memory usage: 17.2+ KB

# %%
df1.describe()
# Out:
#               Mat        Inns          NO        Runs          HS         Ave  \
# count  146.000000  146.000000  146.000000  146.000000  146.000000  146.000000
# mean     7.191781    5.993151    1.000000  160.458904   54.561644   26.183493
# std      2.910895    2.981545    1.150712  160.351344   44.254900   19.807955
# min      1.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      5.250000    3.000000    0.000000   29.250000   16.250000   11.807500
# 50%      8.000000    6.000000    1.000000   99.000000   42.500000   21.515000
# 75%      9.000000    9.000000    1.750000  279.000000   77.750000   40.000000
# max     11.000000   11.000000    5.000000  765.000000  201.000000   95.620000
#
#                BF          SR         100          50           0          4s  \
# count  146.000000  146.000000  146.000000  146.000000  146.000000  146.000000
# mean   174.342466   85.572603    0.273973    0.815068    0.417808   15.335616
# ...

# %%
df1.shape
# Out:
# (146, 15)

# %% [markdown]
# #### THERE ARE TOTAL OF 146 ROWS AND 15 COLUMNS.
# #### NO NULL VALUES PRESENT.
# #### DATA LOADED IN DF1 DATASET.

# %% [markdown]
# # LETS START ANALYSIS.......

# %%
df1
# Out:
#                      Player       Span  Mat  Inns  NO  Runs   HS    Ave   BF  \
# 0             V Kohli (IND)  2023-2023   11    11   3   765  117  95.62  847
# 1           RG Sharma (IND)  2023-2023   11    11   0   597  131  54.27  474
# 2            Q de Kock (SA)  2023-2023   10    10   0   594  174  59.40  555
# 3           R Ravindra (NZ)  2023-2023   10    10   1   578  123  64.22  543
# 4          DJ Mitchell (NZ)  2023-2023   10     9   1   552  134  69.00  497
# ..                      ...        ...  ...   ...  ..   ...  ...    ...  ...
# 141      MADI Hemantha (SL)  2023-2023    2     2   1     4    4   4.00    4
# 142      JR Hazlewood (AUS)  2023-2023   11     5   3     4    2   2.00    5
# 143  Fazalhaq Farooqi (AFG)  2023-2023    6     3   2     2    2   2.00    9
# 144          AT Carey (AUS)  2023-2023    1     1   0     0    0   0.00    2
# 145         Usama Mir (PAK)  2023-2023    4     1   0     0    0   0.00    3
#
#          SR  100  50  0  4s  6s
# ...

# %% [markdown]
# # TOP 10 RUN SCORERS

# %%
Toprun=df1.sort_values('Runs',ascending=False).head(10)

# %%
Toprun
# Out:
#                    Player       Span  Mat  Inns  NO  Runs   HS    Ave   BF  \
# 0           V Kohli (IND)  2023-2023   11    11   3   765  117  95.62  847
# 1         RG Sharma (IND)  2023-2023   11    11   0   597  131  54.27  474
# 2          Q de Kock (SA)  2023-2023   10    10   0   594  174  59.40  555
# 3         R Ravindra (NZ)  2023-2023   10    10   1   578  123  64.22  543
# 4        DJ Mitchell (NZ)  2023-2023   10     9   1   552  134  69.00  497
# 5         DA Warner (AUS)  2023-2023   11    11   0   535  163  48.63  494
# 6           SS Iyer (IND)  2023-2023   11    11   3   530  128  66.25  468
# 7          KL Rahul (IND)  2023-2023   11    10   4   452  102  75.33  498
# 8  HE van der Dussen (SA)  2023-2023   10    10   1   448  133  49.77  530
# 9          MR Marsh (AUS)  2023-2023   10    10   1   441  177  49.00  410
#
#        SR  100  50  0  4s  6s
# 0   90.31    3   6  1  68   9
# 1  125.94    1   3  1  66  31
# 2  107.02    4   0  0  57  21
# ...

# %%
sns.barplot(data=Toprun,x="Runs",y="Player")
plt.title("TOP 10 RUN SCORERS")
plt.show()

# %% [markdown]
# # HIGHEST STRIKE RATE OF PLAYERS HAVING MATCHES MORE THAN 5.

# %%
topsr=df1[df1["Mat"]>5].sort_values(by="SR",ascending=False).head(10)

# %%
topsr
# Out:
#                     Player       Span  Mat  Inns  NO  Runs   HS    Ave   BF  \
# 12        GJ Maxwell (AUS)  2023-2023    9     9   3   400  201  66.66  266
# 16          H Klaasen (SA)  2023-2023   10    10   1   373  109  41.44  280
# 80           MA Wood (ENG)  2023-2023    7     7   4    85   43  28.33   65
# 24           TM Head (AUS)  2023-2023    6     6   0   329  137  54.83  258
# 99  Mujeeb Ur Rahman (AFG)  2023-2023    9     5   1    51   28  12.75   40
# 71         MJ Santner (NZ)  2023-2023   10     7   3   103   36  25.75   81
# 1          RG Sharma (IND)  2023-2023   11    11   0   597  131  54.27  474
# 81         MS Chapman (NZ)  2023-2023    8     6   1    84   39  16.80   71
# 95        Haris Rauf (PAK)  2023-2023    9     5   2    53   35  17.66   45
# 85         DJ Willey (ENG)  2023-2023    6     6   2    78   16  19.50   67
#
#         SR  100  50  0  4s  6s
# 12  150.37    2   0  1  40  22
# 16  133.21    1   1  0  28  19
# 80  130.76    0   0  1   7   5
# ...

# %%
sns.barplot(data=topsr,x="SR",y="Player")
plt.title("TOP 10 STRIKE RATE")
plt.show()

# %% [markdown]
# # HIGHEST Average OF PLAYERS HAVING MATCHES MORE THAN 5.

# %%
topavg=df1[df1["Mat"]>5].sort_values(by="Ave",ascending=False).head(10)

# %%
topavg
# Out:
#                       Player       Span  Mat  Inns  NO  Runs   HS    Ave   BF  \
# 0              V Kohli (IND)  2023-2023   11    11   3   765  117  95.62  847
# 7             KL Rahul (IND)  2023-2023   11    10   4   452  102  75.33  498
# 21  Azmatullah Omarzai (AFG)  2023-2023    9     8   3   353   97  70.60  361
# 4           DJ Mitchell (NZ)  2023-2023   10     9   1   552  134  69.00  497
# 12          GJ Maxwell (AUS)  2023-2023    9     9   3   400  201  66.66  266
# 6              SS Iyer (IND)  2023-2023   11    11   3   530  128  66.25  468
# 13     Mohammad Rizwan (PAK)  2023-2023    9     8   2   395  131  65.83  414
# 3            R Ravindra (NZ)  2023-2023   10    10   1   578  123  64.22  543
# 2             Q de Kock (SA)  2023-2023   10    10   0   594  174  59.40  555
# 24             TM Head (AUS)  2023-2023    6     6   0   329  137  54.83  258
#
#         SR  100  50  0  4s  6s
# 0    90.31    3   6  1  68   9
# 7    90.76    1   2  0  38   9
# ...

# %%
sns.barplot(data=topavg,x="Ave",y="Player")
plt.title("HIGHEST AVERAGE")
plt.show()

# %% [markdown]
# # CORRELATION BETWEEN RUNS AND STRIKE RATE.

# %%
sns.scatterplot(x='Runs', y='SR', data=df1,palette="rainbow",hue="Ave")
plt.title("Runs vs Strike Rate")
plt.show()

# %% [markdown]
# # REGRESSION PLOT BETWEEN RUNS AND STRIKE RATE.

# %%
sns.regplot(data=df1,x="Runs",y="SR")
# Out:
# <Axes: xlabel='Runs', ylabel='SR'>

# %% [markdown]
# # RUNS DISTRIBUTION

# %%
sns.histplot(df1['Runs'], bins=10)
plt.title("Distribution of Runs")
plt.show()

# %% [markdown]
# # CONCLUSION
#
# #### The analysis identified the top 10 run scorers in the tournament and highlighted players with the highest strike rates and batting averages. Bar plots helped compare player performances, while a histogram showed the distribution of runs among players. Additionally, correlation and regression analysis between runs and strike rate were performed to understand the relationship between scoring speed and total runs.
#
# #### The results suggest that players who maintain a good strike rate often tend to accumulate higher runs, although consistency and match participation also play an important role. Overall, this analysis demonstrates how data visualization and statistical techniques can help uncover meaningful insights from sports performance data.

# %% [markdown]
# # BOWLING ANALYSIS

# %%
df2=pd.read_csv(r"C:\@Hardik\Data Science\Project_2023_ODI_WC\archive (1)\ICC MENS ODI WORLD CUP 2023\Bowling records\best_economy_rates.csv")

# %%
df2
# Out:
#                  Player       Span  Mat  Overs Mdns  Balls  Runs Wkts   BBI  \
# 0        R Ashwin (IND)  2023-2023    1   10.0    1     60    34    1  1/34
# 1       JJ Bumrah (IND)  2023-2023   11   91.5    9    551   373   20  4/39
# 2   Mohammad Nabi (AFG)  2023-2023    9   61.3    4    369   254    8  3/28
# 3       KA Maharaj (SA)  2023-2023   10   89.0    1    534   370   15  4/46
# 4       RA Jadeja (IND)  2023-2023   11   93.3    4    561   398   16  5/33
# ..                  ...        ...  ...    ...  ...    ...   ...  ...   ...
# 95    Agha Salman (PAK)  2023-2023    3    5.0    -     30    46    -     -
# 96   Hasan Mahmud (BAN)  2023-2023    2   14.0    -     84   132    3  2/67
# 97     M Pathirana (SL)  2023-2023    2   19.0    -    114   185    2  1/90
# 98    KIC Asalanka (SL)  2023-2023    9    1.0    -      6    10    -     -
# 99     JDS Neesham (NZ)  2023-2023    3   14.3    -     87   157    2  1/32
#
#       Ave   Econ    SR  4  5 10
# ...

# %%
df2.count()
# Out:
# Player    100
# Span      100
# Mat       100
# Overs     100
# Mdns      100
# Balls     100
# Runs      100
# Wkts      100
# BBI       100
# Ave       100
# Econ      100
# SR        100
# 4         100
# 5         100
# 10        100
# dtype: int64

# %%
df2.isnull()
# Out:
#     Player   Span    Mat  Overs   Mdns  Balls   Runs   Wkts    BBI    Ave  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 95   False  False  False  False  False  False  False  False  False  False
# 96   False  False  False  False  False  False  False  False  False  False
# 97   False  False  False  False  False  False  False  False  False  False
# 98   False  False  False  False  False  False  False  False  False  False
# 99   False  False  False  False  False  False  False  False  False  False
#
#      Econ     SR      4      5     10
# 0   False  False  False  False  False
# ...

# %%
df2.info
# Out:
# <bound method DataFrame.info of                  Player       Span  Mat  Overs Mdns  Balls  Runs Wkts   BBI  \
# 0        R Ashwin (IND)  2023-2023    1   10.0    1     60    34    1  1/34
# 1       JJ Bumrah (IND)  2023-2023   11   91.5    9    551   373   20  4/39
# 2   Mohammad Nabi (AFG)  2023-2023    9   61.3    4    369   254    8  3/28
# 3       KA Maharaj (SA)  2023-2023   10   89.0    1    534   370   15  4/46
# 4       RA Jadeja (IND)  2023-2023   11   93.3    4    561   398   16  5/33
# ..                  ...        ...  ...    ...  ...    ...   ...  ...   ...
# 95    Agha Salman (PAK)  2023-2023    3    5.0    -     30    46    -     -
# 96   Hasan Mahmud (BAN)  2023-2023    2   14.0    -     84   132    3  2/67
# 97     M Pathirana (SL)  2023-2023    2   19.0    -    114   185    2  1/90
# 98    KIC Asalanka (SL)  2023-2023    9    1.0    -      6    10    -     -
# 99     JDS Neesham (NZ)  2023-2023    3   14.3    -     87   157    2  1/32
#
# ...

# %%
df2.describe
# Out:
# <bound method NDFrame.describe of                  Player       Span  Mat  Overs Mdns  Balls  Runs Wkts   BBI  \
# 0        R Ashwin (IND)  2023-2023    1   10.0    1     60    34    1  1/34
# 1       JJ Bumrah (IND)  2023-2023   11   91.5    9    551   373   20  4/39
# 2   Mohammad Nabi (AFG)  2023-2023    9   61.3    4    369   254    8  3/28
# 3       KA Maharaj (SA)  2023-2023   10   89.0    1    534   370   15  4/46
# 4       RA Jadeja (IND)  2023-2023   11   93.3    4    561   398   16  5/33
# ..                  ...        ...  ...    ...  ...    ...   ...  ...   ...
# 95    Agha Salman (PAK)  2023-2023    3    5.0    -     30    46    -     -
# 96   Hasan Mahmud (BAN)  2023-2023    2   14.0    -     84   132    3  2/67
# 97     M Pathirana (SL)  2023-2023    2   19.0    -    114   185    2  1/90
# 98    KIC Asalanka (SL)  2023-2023    9    1.0    -      6    10    -     -
# 99     JDS Neesham (NZ)  2023-2023    3   14.3    -     87   157    2  1/32
#
# ...

# %%
df2.shape
# Out:
# (100, 15)

# %%
df2=df2.replace(to_replace='-',value="0")

# %%
cols = ['Mat','Overs','Mdns','Balls','Runs','Wkts','Ave','Econ','SR','4','5','10']

df2[cols] = df2[cols].apply(pd.to_numeric)

# %% [markdown]
# # TOP 10 MOST WICKETS TAKERS.

# %%
top10ball=df2.sort_values(by="Wkts",ascending=False).head(10)

# %%
top10ball
# Out:
#                        Player       Span  Mat  Overs  Mdns  Balls  Runs  Wkts  \
# 21       Mohammed Shami (IND)  2023-2023    7   48.5     4    293   257    24
# 24              A Zampa (AUS)  2023-2023   11   96.0     1    576   515    23
# 74          D Madushanka (SL)  2023-2023    9   78.2     4    470   525    21
# 60             G Coetzee (SA)  2023-2023    8   63.3     1    381   396    20
# 1             JJ Bumrah (IND)  2023-2023   11   91.5     9    551   373    20
# 50  Shaheen Shah Afridi (PAK)  2023-2023    9   81.0     3    486   481    18
# 68              M Jansen (SA)  2023-2023    9   69.0     3    414   450    17
# 83         BFW de Leede (NED)  2023-2023    9   67.0     0    402   487    16
# 12         JR Hazlewood (AUS)  2023-2023   11   93.1     8    559   449    16
# 76           Haris Rauf (PAK)  2023-2023    9   79.0     1    474   533    16
#
#      BBI    Ave  Econ    SR  4  5  10
# 21  7/57  10.70  5.26  12.2  1  3   0
# ...

# %%
sns.barplot(data=top10ball,x="Wkts",y="Player")
plt.title("Top 10 Wicket Takers")
plt.show()

# %% [markdown]
# ##

# %% [markdown]
# # TOP 10  ECONOMIES (BOWLED MORE THAN 10 OVERS IN TOTAL).

# %%
loweco=df2[df2["Balls"]>60].sort_values(by="Econ",ascending=True).head(10)

# %%
loweco
# Out:
#                  Player       Span  Mat  Overs  Mdns  Balls  Runs  Wkts   BBI  \
# 1       JJ Bumrah (IND)  2023-2023   11   91.5     9    551   373    20  4/39
# 2   Mohammad Nabi (AFG)  2023-2023    9   61.3     4    369   254     8  3/28
# 3       KA Maharaj (SA)  2023-2023   10   89.0     1    534   370    15  4/46
# 4       RA Jadeja (IND)  2023-2023   11   93.3     4    561   398    16  5/33
# 6   Kuldeep Yadav (IND)  2023-2023   11   95.1     2    571   424    15   2/7
# 7     Rashid Khan (AFG)  2023-2023    9   86.3     2    519   388    11  3/37
# 8       AK Markram (SA)  2023-2023   10   18.3     1    111    85     1  1/23
# 9      Noor Ahmad (AFG)  2023-2023    4   38.0     1    228   182     5  3/49
# 10        TM Head (AUS)  2023-2023    6   21.0     0    126   101     2  2/21
# 12   JR Hazlewood (AUS)  2023-2023   11   93.1     8    559   449    16  3/38
#
#       Ave  Econ     SR  4  5  10
# 1   18.65  4.06   27.5  1  0   0
# 2   31.75  4.13   46.1  0  0   0
# ...

# %%
sns.barplot(data=loweco,x="Econ",y="Player")
plt.title("TOP 10  ECONOMIES (BOWLED MORE THAN 10 OVERS IN TOTAL).")
plt.show()

# %% [markdown]
# # MOST MAIDENS.

# %%
mdns10=df2.sort_values(by="Mdns",ascending=False).head(10)

# %%
mdns10
# Out:
#                   Player       Span  Mat  Overs  Mdns  Balls  Runs  Wkts  \
# 1        JJ Bumrah (IND)  2023-2023   11   91.5     9    551   373    20
# 12    JR Hazlewood (AUS)  2023-2023   11   93.1     8    559   449    16
# 16         K Rabada (SA)  2023-2023    9   72.5     7    437   364    13
# 31         TA Boult (NZ)  2023-2023   10   91.0     6    546   504    14
# 39  Mohammed Siraj (IND)  2023-2023   11   82.3     6    495   469    14
# 28          A Dutt (NED)  2023-2023    9   77.3     6    465   426    10
# 18       DJ Willey (ENG)  2023-2023    6   51.0     6    306   259    11
# 47          L Ngidi (SA)  2023-2023    8   60.3     6    363   355    10
# 4        RA Jadeja (IND)  2023-2023   11   93.3     4    561   398    16
# 74     D Madushanka (SL)  2023-2023    9   78.2     4    470   525    21
#
#      BBI    Ave  Econ    SR  4  5  10
# 1   4/39  18.65  4.06  27.5  1  0   0
# 12  3/38  28.06  4.81  34.9  0  0   0
# 16  3/33  28.00  4.99  33.6  0  0   0
# ...

# %%
sns.barplot(data=mdns10,x="Mdns",y="Player")
plt.title("TOP 10 MAIDEN OVER LEADERS ")
plt.show()

# %% [markdown]
# # CORRELATION BETWEEN ECONOMY AND MAIDENS.

# %%
sns.scatterplot(data=df2,x="Mdns",y="Econ",palette="rainbow",hue="Wkts")
# Out:
# <Axes: xlabel='Mdns', ylabel='Econ'>

# %% [markdown]
# # CORRELATION BETWEEN ECONOMY AND WICKETS.

# %%
sns.scatterplot(data=df2,x="Wkts",y="Econ",palette="rainbow",hue="Mdns")
# Out:
# <Axes: xlabel='Wkts', ylabel='Econ'>

# %% [markdown]
# # RUNS CONCEDED VS WICKETS (REGRESSION)

# %%
sns.regplot(data=df2,x="Runs",y="Wkts")
# Out:
# <Axes: xlabel='Runs', ylabel='Wkts'>

# %% [markdown]
# # WICKETS DISTRIBUTION WITH KERNEL DISTRIBUTION ESTIMATION

# %%
sns.histplot(data=df2,x="Wkts",bins=10,kde=True)
# Out:
# <Axes: xlabel='Wkts', ylabel='Count'>

# %% [markdown]
# # Conclusion
#
# #### This analysis explored bowling performance using multiple statistical techniques and visualizations. The results show that bowlers with the highest wickets play a crucial role in match outcomes, while bowlers with lower economy rates are effective in restricting the scoring rate. The analysis of maiden overs further highlights bowlers who maintain consistent line and length, creating pressure on the batting side.
#
# #### Correlation analysis indicates a relationship between economy rate and maiden overs, suggesting that bowlers who bowl tighter overs tend to maintain better economy. However, the correlation between economy and wickets is weaker, implying that wicket-taking ability does not always depend on restricting runs. The regression analysis between runs conceded and wickets suggests that bowlers who bowl more frequently tend to concede more runs but also have greater opportunities to take wickets.
#
# #### Overall, the study shows that bowling effectiveness depends on a balance between run control and wicket-taking ability, and different bowlers contribute in different ways to a team's success.

# %% [markdown]
# # FIELDING  ANALYSIS

# %%
df3=pd.read_csv(r"C:\@Hardik\Data Science\Project_2023_ODI_WC\archive (1)\ICC MENS ODI WORLD CUP 2023\Fielding records\most_catches.csv")

# %%
df3
# Out:
#                     Player       Span  Mat  Inns  Ct  Max  Ct/Inn
# 0         DJ Mitchell (NZ)  2023-2023   10    10  11    3   1.100
# 1      M Labuschagne (AUS)  2023-2023   11    11   8    2   0.727
# 2          DA Warner (AUS)  2023-2023   11    11   8    2   0.727
# 3           DA Miller (SA)  2023-2023   10    10   7    2   0.700
# 4          RA Jadeja (IND)  2023-2023   11    11   7    3   0.636
# ..                     ...        ...  ...   ...  ..  ...     ...
# 95    Mohammad Nawaz (PAK)  2023-2023    5     5   1    1   0.200
# 96  Fazalhaq Farooqi (AFG)  2023-2023    6     6   1    1   0.166
# 97       Imam-ul-Haq (PAK)  2023-2023    6     6   1    1   0.166
# 98        CAK Rajitha (SL)  2023-2023    6     6   1    1   0.166
# 99   Vikramjit Singh (NED)  2023-2023    6     6   1    1   0.166
#
# [100 rows x 7 columns]

# %%
 df3.count()
# Out:
# Player    100
# Span      100
# Mat       100
# Inns      100
# Ct        100
# Max       100
# Ct/Inn    100
# dtype: int64

# %%
df3.isnull().sum()
# Out:
# Player    0
# Span      0
# Mat       0
# Inns      0
# Ct        0
# Max       0
# Ct/Inn    0
# dtype: int64

# %%
df3.info
# Out:
# <bound method DataFrame.info of                     Player       Span  Mat  Inns  Ct  Max  Ct/Inn
# 0         DJ Mitchell (NZ)  2023-2023   10    10  11    3   1.100
# 1      M Labuschagne (AUS)  2023-2023   11    11   8    2   0.727
# 2          DA Warner (AUS)  2023-2023   11    11   8    2   0.727
# 3           DA Miller (SA)  2023-2023   10    10   7    2   0.700
# 4          RA Jadeja (IND)  2023-2023   11    11   7    3   0.636
# ..                     ...        ...  ...   ...  ..  ...     ...
# 95    Mohammad Nawaz (PAK)  2023-2023    5     5   1    1   0.200
# 96  Fazalhaq Farooqi (AFG)  2023-2023    6     6   1    1   0.166
# 97       Imam-ul-Haq (PAK)  2023-2023    6     6   1    1   0.166
# 98        CAK Rajitha (SL)  2023-2023    6     6   1    1   0.166
# 99   Vikramjit Singh (NED)  2023-2023    6     6   1    1   0.166
#
# [100 rows x 7 columns]>

# %%
df3.describe
# Out:
# <bound method NDFrame.describe of                     Player       Span  Mat  Inns  Ct  Max  Ct/Inn
# 0         DJ Mitchell (NZ)  2023-2023   10    10  11    3   1.100
# 1      M Labuschagne (AUS)  2023-2023   11    11   8    2   0.727
# 2          DA Warner (AUS)  2023-2023   11    11   8    2   0.727
# 3           DA Miller (SA)  2023-2023   10    10   7    2   0.700
# 4          RA Jadeja (IND)  2023-2023   11    11   7    3   0.636
# ..                     ...        ...  ...   ...  ..  ...     ...
# 95    Mohammad Nawaz (PAK)  2023-2023    5     5   1    1   0.200
# 96  Fazalhaq Farooqi (AFG)  2023-2023    6     6   1    1   0.166
# 97       Imam-ul-Haq (PAK)  2023-2023    6     6   1    1   0.166
# 98        CAK Rajitha (SL)  2023-2023    6     6   1    1   0.166
# 99   Vikramjit Singh (NED)  2023-2023    6     6   1    1   0.166
#
# [100 rows x 7 columns]>

# %%
df3.shape
# Out:
# (100, 7)

# %%
cols = ['Mat','Inns','Ct','Max','Ct/Inn']

df3[cols] = df3[cols].apply(pd.to_numeric)

# %% [markdown]
# # Top 10 Most Catchers

# %%
catchtaken=df3.sort_values(by='Ct',ascending=False).head(10)

# %%
catchtaken
# Out:
#                   Player       Span  Mat  Inns  Ct  Max  Ct/Inn
# 0       DJ Mitchell (NZ)  2023-2023   10    10  11    3   1.100
# 2        DA Warner (AUS)  2023-2023   11    11   8    2   0.727
# 1    M Labuschagne (AUS)  2023-2023   11    11   8    2   0.727
# 3         DA Miller (SA)  2023-2023   10    10   7    2   0.700
# 4        RA Jadeja (IND)  2023-2023   11    11   7    3   0.636
# 9         MA Starc (AUS)  2023-2023   10    10   6    3   0.600
# 10         V Kohli (IND)  2023-2023   11    11   6    2   0.545
# 8         DP Conway (NZ)  2023-2023   10    10   6    2   0.600
# 7     Shubman Gill (IND)  2023-2023    9     9   6    2   0.666
# 6   SA Engelbrecht (NED)  2023-2023    8     8   6    2   0.750

# %%
sns.barplot(data=catchtaken,x="Ct",y="Player")
plt.title("Top 10 Most Catchers")
plt.show()

# %% [markdown]
# # TOP 10 HIGHEST CATCHERS PER INNING

# %%
perinn=df3.sort_values("Ct/Inn",ascending=False).head(10)

# %%
perinn
# Out:
#                   Player       Span  Mat  Inns  Ct  Max  Ct/Inn
# 39  Saqib Zulfiqar (NED)  2023-2023    2     2   3    2   1.500
# 11       Usama Mir (PAK)  2023-2023    4     4   5    2   1.250
# 0       DJ Mitchell (NZ)  2023-2023   10    10  11    3   1.100
# 57  FDM Karunaratne (SL)  2023-2023    2     2   2    2   1.000
# 40     Agha Salman (PAK)  2023-2023    3     3   3    2   1.000
# 81       SA Abbott (AUS)  2023-2023    1     1   1    1   1.000
# 5        BA Stokes (ENG)  2023-2023    6     6   6    3   1.000
# 6   SA Engelbrecht (NED)  2023-2023    8     8   6    2   0.750
# 41    Fakhar Zaman (PAK)  2023-2023    4     4   3    2   0.750
# 1    M Labuschagne (AUS)  2023-2023   11    11   8    2   0.727

# %%
sns.barplot(data=perinn,x="Ct/Inn",y="Player")
plt.title("Top 10 highest catchers per inning")
plt.show()

# %% [markdown]
# # CATCH DISTRIBUTION AMONG PLAYERS

# %%
sns.histplot(data=df3,x="Ct",bins=10,kde=True)
# Out:
# <Axes: xlabel='Ct', ylabel='Count'>

# %% [markdown]
# ## CONCLUSION
# ### The fielding analysis highlights differences in players’ catching performance. Top catchers show overall contribution, while catches per innings reflects efficiency. The distribution indicates most players are average, with a few standout fielders. Using both total and normalized metrics gives better insights. Overall, fielding plays a key role in team performance.
